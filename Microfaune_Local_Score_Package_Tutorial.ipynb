# %%
from microfaune_local_score import *
import pandas as pd

# %% [markdown]
# ## Running Moment to Moment Labeling System on a Directory of WAV Files

# %%
path = "./TEST/"

# %% [markdown]
# ### Dictionary that defines the isolation technique and parameters used to generate automated labels

# %%
isolation_parameters = {
    "technique" : "steinberg",
    "threshold_type" : "median",
    "threshold_const" : 2.0,
    "bi_directional_jump" : 1.0
}

# %%
automated_df = generate_automated_labels(path,isolation_parameters)

# %% [markdown]
# ### Pandas Ouput of Automated Labeling

# %%
automated_df
# Out:
#      FOLDER                 IN FILE  CHANNEL  CLIP LENGTH  SAMPLE RATE  \
# 0   ./TEST/     20190622_210000.WAV        0    60.000000        44100
# 1   ./TEST/     20190622_210000.WAV        0    60.000000        44100
# 2   ./TEST/     20190622_210000.WAV        0    60.000000        44100
# 3   ./TEST/     20190623_222000.WAV        0    60.000000        44100
# 4   ./TEST/     20190623_222000.WAV        0    60.000000        44100
# 5   ./TEST/     20190623_222000.WAV        0    60.000000        44100
# 6   ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 7   ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 8   ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 9   ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 10  ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 11  ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 12  ./TEST/  BlackFacedAntbird1.wav        0    31.216327        44100
# 13  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 14  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 15  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 16  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 17  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 18  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 19  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 20  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 21  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 22  ./TEST/       HowlerMonkey1.WAV        0    60.000000        44100
# 23  ./TEST/     20190624_152000.WAV        0    60.000000        44100
# 24  ./TEST/     20190624_152000.WAV        0    60.000000        44100
# 25  ./TEST/     20190624_152000.WAV        0    60.000000        44100
# 26  ./TEST/      ScreamingPiha2.wav        0    33.933061        44100
# 27  ./TEST/      ScreamingPiha2.wav        0    33.933061        44100
# 28  ./TEST/      ScreamingPiha2.wav        0    33.933061        44100
# 29  ./TEST/      ScreamingPiha2.wav        0    33.933061        44100
# 30  ./TEST/      ScreamingPiha2.wav        0    33.933061        44100
#
#        OFFSET   DURATION MANUAL ID
# 0    0.000000  34.056122      bird
# 1   37.229116   9.005578      bird
# 2   51.588231   6.755442      bird
# 3    0.000000   6.567347      bird
# 4   12.106463   2.000000      bird
# 5   18.276939   8.472041      bird
# 6    0.000000   1.371156      bird
# 7    2.827551   3.438231      bird
# 8    6.423129   2.301565      bird
# 9    8.812449   2.742313      bird
# 10  14.402993   4.319728      bird
# 11  19.088844   3.925374      bird
# 12  25.908844   4.598095      bird
# 13   0.000000   4.525986      bird
# 14   4.776122   4.806871      bird
# 15  12.060068   2.023197      bird
# 16  16.212381   2.000000      bird
# 17  22.522041   3.994966      bird
# 18  26.859932   3.438231      bird
# 19  35.234150   5.711565      bird
# 20  43.793946   4.157347      bird
# 21  48.433401   4.899660      bird
# 22  55.160612   4.366122      bird
# 23   7.722177   5.108435      bird
# 24  13.567891   2.000000      bird
# 25  17.093878   3.647007      bird
# 26   0.000000  12.227483      bird
# 27  13.103946   2.463946      bird
# 28  20.851837   5.456395      bird
# 29  26.883129   3.345442      bird
# 30  31.313810   2.231973      bird

# %% [markdown]
# ### Function that gathers statistics about the duration of labels

# %%
annotation_duration_statistics(automated_df)
# Out:
#    COUNT  MODE      MEAN  STANDARD DEVIATION       MIN        Q1    MEDIAN  \
# 0     31   2.0  5.353472            5.725178  1.371156  2.603129  4.157347
#
#          Q3        MAX
# 0  5.282415  34.056122

# %% [markdown]
# ### Human Manual Labels for Comparison

# %%
manual_df = pd.read_csv("Manual_Labels.csv")
manual_df
# Out:
#                                                FOLDER                 IN FILE  \
# 0   /home/jacob/Acoustic-Species-Identification/pa...      ScreamingPiha2.wav
# 1   /home/jacob/Acoustic-Species-Identification/pa...      ScreamingPiha2.wav
# 2   /home/jacob/Acoustic-Species-Identification/pa...      ScreamingPiha2.wav
# 3   /home/jacob/Acoustic-Species-Identification/pa...      ScreamingPiha2.wav
# 4   /home/jacob/Acoustic-Species-Identification/pa...      ScreamingPiha2.wav
# 5   /home/jacob/Acoustic-Species-Identification/pa...     20190622_210000.WAV
# 6   /home/jacob/Acoustic-Species-Identification/pa...     20190622_210000.WAV
# 7   /home/jacob/Acoustic-Species-Identification/pa...     20190622_210000.WAV
# 8   /home/jacob/Acoustic-Species-Identification/pa...     20190622_210000.WAV
# 9   /home/jacob/Acoustic-Species-Identification/pa...     20190622_210000.WAV
# 10  /home/jacob/Acoustic-Species-Identification/pa...     20190623_222000.WAV
# 11  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 12  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 13  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 14  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 15  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 16  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 17  /home/jacob/Acoustic-Species-Identification/pa...     20190624_152000.WAV
# 18  /home/jacob/Acoustic-Species-Identification/pa...  BlackFacedAntbird1.wav
# 19  /home/jacob/Acoustic-Species-Identification/pa...  BlackFacedAntbird1.wav
# 20  /home/jacob/Acoustic-Species-Identification/pa...  BlackFacedAntbird1.wav
# 21  /home/jacob/Acoustic-Species-Identification/pa...  BlackFacedAntbird1.wav
# 22  /home/jacob/Acoustic-Species-Identification/pa...       HowlerMonkey1.WAV
# 23  /home/jacob/Acoustic-Species-Identification/pa...       HowlerMonkey1.WAV
# 24  /home/jacob/Acoustic-Species-Identification/pa...       HowlerMonkey1.WAV
#
#     CHANNEL  CLIP LENGTH  OFFSET  DURATION  MANUAL ID
# 0         0    33.933061   0.000     5.373          1
# 1         0    33.933061  10.590     5.585          1
# 2         0    33.933061  22.000     4.000          1
# 3         0    33.933061  27.200     0.900          1
# 4         0    33.933061  29.000     4.500          1
# 5         0    60.000000   0.000     9.700          1
# 6         0    60.000000  11.500    16.675          1
# 7         0    60.000000  29.500    15.000          1
# 8         0    60.000000  48.525     1.000          1
# 9         0    60.000000  50.500     8.000          1
# 10        0    60.000000  14.500    12.500          1
# 11        0    60.000000   1.200     0.450          1
# 12        0    60.000000   4.000     0.300          1
# 13        0    60.000000   7.400     0.600          1
# 14        0    60.000000  10.500     0.800          1
# 15        0    60.000000  20.800     0.500          1
# 16        0    60.000000  28.000     0.400          1
# 17        0    60.000000  34.000     1.000          1
# 18        0    31.200000   0.000     4.100          1
# 19        0    31.200000   5.000     1.500          1
# 20        0    31.200000   9.800     5.200          1
# 21        0    31.200000  21.500     5.500          1
# 22        0    60.000000   0.000    10.900          1
# 23        0    60.000000  11.500    13.000          1
# 24        0    60.000000  25.000    34.900          1

# %%
annotation_duration_statistics(manual_df)
# Out:
#    COUNT  MODE     MEAN  STANDARD DEVIATION  MIN   Q1  MEDIAN   Q3   MAX
# 0     25   1.0  6.49532            7.604367  0.3  0.9     4.5  9.7  34.9

# %% [markdown]
# ## Different Combinations of Local Score Visualization Graphs

# %% [markdown]
# ### Baseline Graph without any annotations

# %%
clip_path = "./TEST/ScreamingPiha2.wav"
local_score_visualization(clip_path)

# %% [markdown]
# ### Baseline graph with log scale

# %%
local_score_visualization(clip_path,log_scale = True)

# %% [markdown]
# ### Graph with Automated Labeling

# %%
local_score_visualization(clip_path,automated_df = True, isolation_parameters = isolation_parameters)

# %% [markdown]
# ### Graph with Human Labelling

# %%
local_score_visualization(clip_path,human_df = manual_df[manual_df["IN FILE"] == "ScreamingPiha2.wav"])

# %% [markdown]
# ### Graph with Both Automated and Human Labels
#     Orange ==> True Positive
#     Red ==> False Negative
#     Yellow ==> False Positive
#     White ==> True Negative

# %%
local_score_visualization(clip_path,automated_df = True,isolation_parameters=isolation_parameters,human_df = manual_df[manual_df["IN FILE"] == "ScreamingPiha2.wav"])

# %% [markdown]
# ### Another Visualization of True Positives, False Positives, False Negatives, and True Negatives

# %%
automated_piha_df = automated_df[automated_df["IN FILE"] == "ScreamingPiha2.wav"]
manual_piha_df = manual_df[manual_df["IN FILE"] == "ScreamingPiha2.wav"]
piha_stats = bird_label_scores(automated_piha_df,manual_piha_df,plot_fig=True)

# %%
piha_stats

# %% [markdown]
# ### Function that generates statistics to gauge efficacy of automated labeling compared to human labels

# %%
statistics_df = automated_labeling_statistics(automated_df,manual_df)
statistics_df

# %% [markdown]
# ### Function that takes the statistical ouput of all of the clips and gets the equivalent global scores

# %%
global_dataset_statistics(statistics_df)

# %% [markdown]
# ### Function that takes in the manual and automated labels for a clip and outputs human label-by-label IoU Scores. Used to derive statistics that measure how well a system is isolating desired segments of audio clips

# %%
Intersection_over_Union_Matrix = clip_IoU(automated_piha_df,manual_piha_df)
print(Intersection_over_Union_Matrix)

# %% [markdown]
# ### Function that turns the IoU Matrix of a clip into true positive and false positives values, as well as computing the precision

# %%
matrix_IoU_Scores(Intersection_over_Union_Matrix,manual_piha_df,0.5)

# %% [markdown]
# ### Wrapper function that takes matrix_IoU_Scores across multiple clips. Allows user to modify the threshold that determines whether or not a label is a true positive.

# %%
stats_df = dataset_IoU_Statistics(automated_df,manual_df,threshold = 0.8)
stats_df

# %% [markdown]
# ### Function that takes the output of dataset_IoU Statistics and ouputs a global count of true positives and false positives, as well as computing common metrics across the dataset

# %%
global_stats_df = global_IoU_Statistics(stats_df)
global_stats_df

# %%
manual_df_with_IoU = dataset_IoU(automated_df,manual_df)

# %%
manual_df_with_IoU
